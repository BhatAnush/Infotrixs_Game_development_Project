# %% [markdown]
# **Level**-**1**

# %%
import time

# Global variables
player_name = ""
starting_location = ""
resources = []

# Function to print text with a typewriter effect
def print_slow(text):
    for char in text:
        print(char, end='', flush=True)
        time.sleep(0.03)
    print()

# Function to print text in bold
def print_slow_bold(text):
    for char in text:
        print(f"\033[1m{char}\033[0m", end='', flush=True)
        time.sleep(0.03)
    print()

# Function to prompt the player for a choice
def get_choice(options):
    while True:
        print_slow("Choose an option:")
        for idx, option in enumerate(options, start=1):
            print_slow(f"{idx}. {option}")
        try:
            choice = int(input("> "))
            if 1 <= choice <= len(options):
                return choice
            else:
                print_slow("Invalid choice. Please select a valid option.\n")
        except ValueError:
            print_slow("Invalid input. Please enter a number.\n")

# Function for Chapter 1: The Forsaken Island
def chapter1():
    global starting_location, resources, colors

    print_slow_bold(f"Welcome {player_name}, to the mystical world of Hell's Paradise!")
    print()
    print_slow("In the mystical world of \"Hell's Paradise\", where demons and sorcery roam freely,")
    print_slow("a notorious assassin named Haru has been condemned to a life sentence on the secluded island of Tenguu.")
    print_slow("The island is said to harbor the Elixir of Immortality,")
    print_slow("and the Shogunate has tasked Haru with finding it or facing an eternity of torment.")
    print_slow("Your adventure begins as you take on the role of Haru, the Immortal Slayer.")
    print_slow("You wake up on the shores of Tenguu, a treacherous island.")
    print()
    print_slow_bold("LEVEL 1: The Forsaken Island")
    print()
    print_slow("You wake up on the shores of Tenguu, a treacherous landscape filled with dangerous creatures and powerful sorcery.")
    print_slow("The island is divided into different regions, each with its challenges and secrets to uncover.")
    print()
    #print_slow_bold("Choose your starting location:")
    print_slow_bold("Chapter 1. The Enchanted Forest: Explore the lush forest, home to mystical creatures and potent herbs.")
    print()
    print_slow("You have chosen The Enchanted Forest. Your journey begins now!")
    print_slow("As you venture deep into the forest, you encounter mystical creatures like fairies and spirits.")
    print_slow("You collect some mystical herbs, which might come in handy later.")
    print()
    print_slow("You are exploring this enchanted forest, trying to find any clue regarding Elixir.")
    print_slow("After some exploring you get tired and sit under a tree. You come accross a wired insect which is cross-breed between a bee and a butterfly.")
    print_slow("Since you dont know if this insect is venomous or not, so you try to avoid get stung by it as much as possible.")
    print_slow("But end up getting stung by this insect on your left arm.")
    print()
    print_slow("You have two choices: either 1. be clueless and panic, which in turn kills you or 2. amputate your arm and survive.")
    choice = get_choice(["be clueless and panic, which in turn kills you", "amputate your arm and survive"])

    if choice == 1:
            print_slow_bold("GAME OVER!!! YOU ARE DEAD.")
            print_slow_bold(f"SORRY, {player_name}! You are dead now.\n")
            play_again()
    else:  # Changed 'else choice == 2' to 'else' since 'choice == 2' is not necessary
            print_slow_bold("CONGRATULATIONS!!! YOU SURVIVED!")
            print()
            print_slow("After surviving the insect bite, you explore deeper into the woods and you come across a sacred structure.")
            print_slow("You enter the sacred structure you are in a dimly lit hallway, and you see two huge doors on both right and left side of you.")
            choice = get_choice(["Right", "Left"])
            if choice == 1:
              print_slow("After opening the right door, you enter in and come across a monster. You try to fight it but ends up loosing the fight and get killed.")
              print_slow_bold("GAME OVER!!! YOU ARE DEAD.")
              print_slow_bold(f"SORRY, {player_name}! You are dead now.\n")
              play_again()

            else:
              print_slow("You find a box inside which there is a booklet and some ingredients.\n"
                        "When you read the booklet you get to know how to regenerate any amputated body parts.\n"
                        "You follow the methods and use those ingredients and drink that potion.\n"
                        "Your left arm gets regenerated and you survive!")
    print()
    print_slow("You furhter start to explore the island.")
    print_slow_bold(f"Congratulations, {player_name}! You are now at The Volcanic Peaks.\n")

    print_slow_bold("Chapter 2. The Volcanic Peaks: Brave the fiery mountains, where fierce demons reside.")
    print()
    print_slow("You are at one of the world's highest mountains.\n"
               "You can see different creatures here, and some may be too dangerous, so be careful during your journey on this mountain.")
    print_slow("You can hear creepy sounds coming from the west side of this mountain. Do you want to follow the creepy sound?")
    choice = get_choice(["Yes", "No"])


    if choice == 1:
        print_slow("You are able to see different creatures drinking water. There is something hanging over there. Do you want to pick it up?")
        choice = get_choice(["Yes", "No"])

        if choice == 1:
            print_slow("It was a clue to find the Elixir!\n"
                       "You see the creatures near the water, right?\n"
                       "Don't look into their eyes. Wait for some time, and every creature will move to their place, except one.\n"
                       "It was the tallest among all, but don't worry; it's the one you can seek help from.\n"
                       "The first part is under the water, and only that animal can help you get the first part for the Elixir.\n"
                       "Do you want to go near the creature?")
            choice = get_choice(["Yes"])

            if choice == 1:
                print_slow(f"Hello {player_name}, how are you?\n"
                           "I am Jerry the Demon - I know all about you and the purpose of your visit too.\n"
                           "You should dive inside the water; you can find the first part.")
                choice = get_choice(["Dive into the water.", "Don't dive."])

                if choice == 1:
                    print_slow("After diving into the water, you were not able to find the 1st clue to the Elixir.\n"
                               "You try to search for it as much as possible but you end up dying due to suffocation.")
                    print_slow_bold("GAME OVER!!! YOU ARE DEAD.")
                    print_slow_bold(f"SORRY, {player_name}! You are dead now.\n")
                    play_again()
                else:
                    print_slow("You are clever enough not to dive into the water when the demon is there.\n"
                               "Jerry says that only he can get the 1st clue to the Elixir. He gives it to you and directs you to go towards the east.\n"
                               "Also, he tells you a code which is 'ORANGE, WHITE, GREEN' and tells you if any help is required from then then all you have to do is to call for him.")
                    print()
                    print_slow_bold("CONGRATULATIONS ON FINDING THE 1ST CLUE FOR THE ELIXIR!!!")
                    print_slow_bold(f"Congratulations, {player_name}! You are now at The Cursed Ruins.\n")
            else:
                print_slow_bold("You were eaten by the creatures.")
                print_slow_bold("GAME OVER!!! YOU ARE DEAD.")
                print_slow_bold(f"SORRY, {player_name}! You are dead now.\n")
                play_again()

        else:
            print_slow_bold("You were eaten by the creatures.")
            print_slow_bold("GAME OVER!!! YOU ARE DEAD.")
            print_slow_bold(f"SORRY, {player_name}! You are dead now.\n")
            play_again()
    else:
        print_slow_bold("You get lost in the mountain and end up dead.")
        print_slow_bold("GAME OVER!!! YOU ARE LOST IN THIS MOUNTAIN.")
        print_slow_bold(f"SORRY, {player_name}! You are dead now.\n")
        play_again()

        print()
    print_slow_bold("Chapter 3.The Cursed Ruins: Investigate the ancient ruins, rumored to hold hidden knowledge.")
    print()
    print_slow("This is the Ancient Ruins, and here you can see a lot of ancient things.\n"
               f"Can you hear your name from the west side? {player_name} {player_name} {player_name}. I think it is coming from the ancient trunk box. Do you want to open it?")
    choice = get_choice(["Open the trunk box", "Don't open the trunk box."])

    if choice == 1:
      print_slow("You released ancient demon from that box, which initially ruined this place. That demon kills you and starts gaining power. ")
      print_slow_bold("GAME OVER!!! YOU ARE DEAD.")
      print_slow_bold(f"SORRY, {player_name}! You are dead now.\n")
      play_again()

    else:
      print_slow("There is a refliction on the mirror and you notice something written on it.")
      print()
      print_slow(f"Hi {player_name}, welcome to the Ancient Ruins.\n"
                 f"You can find one part of the Elixir here, but you should not follow the noise {player_name} {player_name} {player_name}.\n"
                 "Instead, you go in the opposite direction of that sound.")
      print()
      print_slow_bold("Well, now you can see a set of pots. Try to arrange them in order. Do you remember the colors Jerry said???")
      #Enter the names of the colors Jerry said.
      #colors = input("Choose colors in the correct order: ")
      while True:
            colors_input = input("Enter the colors in the correct order, separated by spaces: ")
            colors_list = colors_input.strip().split()

            if colors_list == ["Orange", "White", "Green"]:
                print_slow_bold("Correct colors! You arranged the pots correctly.")
                break
            else:
                print_slow_bold("The color names are wrong, please type them correctly.")

      print()
      print_slow("Continue with your adventure to find the Elixir!!!")


# Function to start the game
def start_game():
    global player_name

    print_slow_bold("Welcome to Hell's Paradise: The Immortal Slayer!")
    print_slow_bold("Enter your name:")
    player_name = input("> ")

    print_slow_bold(f"Hello, {player_name}! Your adventure begins now.\n")
    chapter1()

# Function to restart/ play the gaim again.

def play_again():
    choice = input("Do you want to play again? (yes/no): ")
    if choice.lower() == "yes":
        start_game()
    else: #choice.lower() == "no":
        print_slow_bold("Thank you for playing!")
        start_game()

if __name__ == "__main__":
    start_game()
# Out:
# Welcome to Hell's Paradise: The Immortal Slayer!
# Enter your name:
# Hello, Anu! Your adventure begins now.
#
# Welcome Anu, to the mystical world of Hell's Paradise!
#
# In the mystical world of "Hell's Paradise", where demons and sorcery roam freely,
# a notorious assassin named Haru has been condemned to a life sentence on the secluded island of Tenguu.
# The island is said to harbor the Elixir of Immortality,
# and the Shogunate has tasked Haru with finding it or facing an eternity of torment.
# Your adventure begins as you take on the role of Haru, the Immortal Slayer.
# You wake up on the shores of Tenguu, a treacherous island.
#
# LEVEL 1: The Forsaken Island
#
# You wake up on the shores of Tenguu, a treacherous landscape filled with dangerous creatures and powerful sorcery.
# The island is divided into different regions, each with its challenges and secrets to uncover.
#
# ...

# %% [markdown]
# **Level**-**2**

# %%
def level_2():
    print_slow_bold("\nLEVEL 2: Allies and Rivals")
    print_slow("\nWELCOME TO CHAPTER 1 - 'ALLIES AND RIVALS'")
    print_slow("Finding the Elixir is so hard, and some of the parts were already found by other Elixir searching persons. You should defeat them to acquire those parts from them to get the Elixir you need.")
    print_slow("\nTHE PERSON KASUMI - SKILLED SWORDSMAN")
    print_slow("Kasumi, a skilled swordsman, is seeking the Elixir for her clan's survival. You need some weapon to defeat Kasumi so that you can get the other part from her.")

    choice = input("\nThere you see some of the training items which were used by Kasumi. Press 1 to view the weapons available here...")

    if choice == "1":
        kasumi_fight()

def kasumi_fight():
    print_slow("\nYou find three weapons in good condition: Samurai Sword, Ninja Throwing Star, Wooden Swords.")
    weapon_choice = input("\nPick any one to defeat Kasumi (SAMURAI SWORD/NINJA THROWING STAR/WOODEN SWORDS): ")

    if weapon_choice.upper() == "SAMURAI SWORD":
        print_slow("\nLet's try to defeat her with the Samurai Sword.")
        print_slow("Well tried, but you can't defeat her with this Samurai Sword.")
        print_slow("Your adventure won't stop here!! Waiting for you again...")
        play_again()
    elif weapon_choice.upper() == "NINJA THROWING STAR":
        print_slow("\nLet's try to defeat her with the Ninja Throwing Star.")
        print_slow("Well tried, but you can't defeat her with this Ninja Throwing Star.")
        print_slow("Your adventure won't stop here!! Waiting for you again...")
        play_again()
    elif weapon_choice.upper() == "WOODEN SWORDS":
        print_slow("\nLet's try to defeat her with the Wooden Swords.")
        print_slow("Congratulations! You defeat Kasumi.")
        print_slow("You find the other part for the Elixir.")
        level_3()
    else:
        print_slow("\nInvalid choice. Please try again.")
        kasumi_fight()

def level_3():
    print_slow_bold("\nCHAPTER 2 - GREETINGS")
    print_slow("Jiro - a rogue sorcerer, is in search of forbidden magic to gain ultimate power.")
    print_slow("Jiro is a powerful magic man. If he finds the other part of the Elixir, he will destroy the world with his magic power.")
    print_slow("\nYou need to defeat Jiro to get the Elixir part from him and save the world.")
    print_slow("You don't have any idea to defeat him... Let's try to find some hint.")

    choice = input("\nOn your right, there seems to be something. Press 1 to explore it: ")

    if choice == "1":
        jiro_hint()

def jiro_hint():
    print_slow("\nYou are on the right path. Jiro is powerful than you think. It is impossible to defeat him with your power.")
    print_slow("So try to steal the part when he is busy doing some other work.")
    print_slow("He used to sleep in the morning till 10:00 AM. So try to steal before that time.")

    steal_time = input("\nLet's steal the Elixir part. Choose the time to steal (9:00 AM / 8:00 AM / 10:00 AM): ")

    if steal_time == "10:00 AM":
        print_slow("\nJiro sleeps till 10:00 AM, and you chose the wrong timing.")
        print_slow("Sorry, you were killed by Jiro with his magic.")
        print_slow("Your adventure won't stop here!! Waiting for you again...")
        play_again()
    elif steal_time == "9:00 AM":
        print_slow("\nYou chose almost the perfect timing to steal, but Jiro wakes up and you were killed by him.")
        print_slow("Your adventure won't stop here!! Waiting for you again...")
        play_again()
    elif steal_time == "8:00 AM":
        print_slow("\nYou chose the right timing to steal the Elixir part.")
        print_slow("You got the Elixir part, and Jiro started losing his magical powers.")
        CHAPTER_3()
    else:
        print_slow("\nInvalid choice. Please try again.")
        jiro_hint()

def CHAPTER_3():
    print_slow_bold("\nCHAPTER 3: Rin")
    print_slow("Rin is the next person. Let's try to find Rin and get the part from him.")
    print_slow("You think Rin would stay in the north because it is the place for demons as he was a former demon.")
    choice = input("\nLet's go towards north. The road is splitting into two ways. Choose the path to travel (RIGHT/LEFT): ")

    if choice.upper() == "RIGHT":
        print_slow("\nYou were killed by the night demons, and your Elixir is now in their hands. You lost the game.")
        print_slow("Your adventure won't stop here!! Waiting for you again...")
        play_again()
    elif choice.upper() == "LEFT":
        print_slow("\nYou are on the right path. Let's find Rin.")
        print_slow("Rin is a former demon, and you heard the news that he is not a demon anymore.")
        rin_interaction()

def rin_interaction():
    print_slow("\nYou see Rin ahead.")
    print_slow("Choose the option:")
    print_slow("1. To speak with Rin")
    print_slow("2. Fight with Rin")

    choice = input()

    if choice == "1":
        print_slow("\nRin, you know what? The demons are trying to acquire the Elixir so that they can change this world for the bad. I need your help.")
        print_slow("Rin: You believed me and came here. I was glad to help you. What do you want?")

        player_name = "{NAME}"  # You can replace "{NAME}" with the player's name.
        print_slow(f"{player_name}: I found some of the parts of the Elixir, and I need the part from you too so that I can get the Elixir, and there is no ending for me. I want to do good things with this power.")
        print_slow("Rin: As you believed me, I too believe you, {player_name}.")
        print_slow("Rin: Wait, I will bring the part which I have.")
        print_slow("Rin gives you the Elixir part.")
        print_slow("Rin: Take this part, and do remember that this part was stolen from demons and preventing them. Don't lose this to demons.")
        print_slow("Rin: If you want any help, just say 'RIN HELP,' and I will be there at any cost.")
        print_slow(f"{player_name}: Thanks, Rin. Sure, I will collect all the parts and meet you soon.")
        print_slow("BYE...\n")

        print_slow("You are feeling powerful, a little before getting the Elixir. So imagine if you find the Elixir, you can live forever and do good things for this world.")
        print_slow("Congratulations! You have completed the game. Thank you for playing Hell's Paradise: The Immortal Slayer")

# %% [markdown]
# **Level**-**3**

# %%
def demons_hunt():
    print_slow_bold("Level 3 - Trials of Immortality: ")
    print_slow_bold("Chapter 1")
    print_slow("As you move deep into tenguu, you start hearing creepy sounds.")
    print_slow("The sound keeps increasing, and you discover the demons surrounding the elixir.")

    choice1 = input("Let's fight the demons and get the elixir - fight | seek help: ").lower()

    if choice1 == "fight":
        print_slow("You tried to battle, but the demons are too powerful.")
        print_slow("Your adventure won't stop here! waiting for you again........")
        print_slow_bold("GAME OVER!!! YOU ARE LOST.")
        print_slow_bold(f"SORRY, {player_name}! You are dead now.\n")
        play_again()
    elif choice1 == "seek help":
        friend_choice = input("Whom do you want to call for help? rin | monkey: ").lower()

        if friend_choice == "rin":
            print_slow(f"rin - {player_name}, i will divert the demons, and the monkey will steal the part.")
            print_slow(f"Well done {player_name}, you have collected the part of elixir and let's move to the next chapter!")
            sorcerers_riddle()

            return True



        elif friend_choice == "monkey":
            print_slow("Monkey - i will help you. you need to divert the demons, and i can get that part from there.")
            print_slow("You tried to divert the demons, but you were killed.")
            print_slow("Your adventure won't stop here! waiting for you again........")
            print_slow_bold("GAME OVER!!! YOU ARE LOST.")
            print_slow_bold(f"SORRY, {player_name}! You are dead now.\n")
            play_again()



    else:
        print_slow_bold("Invalid choice.")
        return False
def sorcerers_riddle():
    print_slow_bold("Chapter 2 - Sorcerer's riddle")
    print_slow_bold("Riddle 1:")
    print_slow("One rabbit saw 6 elephants while going towards the river.")
    print_slow("Every elephant saw 2 monkeys going towards the river.")
    print_slow("Every monkey holds one tortoise in their hands.")

    riddle1_answer = input("How many animals are going towards the river? a) 14 b) 11 c) 8 d) 5: ").lower()
    if riddle1_answer != "5":
        print_slow("You have entered the wrong answer. try to solve the riddle to unlock the passage.")
        print_slow("Your adventure won't stop here! waiting for you again........")
        print_slow_bold("GAME OVER!!! YOU ARE LOST.")
        print_slow_bold(f"SORRY, {player_name}! You are dead now.\n")
        play_again()
        return False

    print_slow_bold("You have cleared this riddle.")

    print_slow_bold("Riddle 2:")
    print_slow("I touch your face, i'm in your words, i'm lack of space and beloved by birds. who am i?")

    riddle2_answer = input("a) tree b) water c) feather d) air: ").lower()
    if riddle2_answer != "air":
        print_slow("You have chosen the wrong answer. try to solve the riddle to unlock the passage.")
        print_slow("Your adventure won't stop here! waiting for you again........")
        print_slow_bold("GAME OVER!!! YOU ARE LOST.")
        print_slow_bold(f"SORRY, {player_name}! You are dead now.\n")
        play_again()


    print_slow_bold("You have cleared this riddle.")
    print_slow("You have opened the hidden passage.")
    print_slow("Go forward into this passage to enter into the next Chapter.")
    elemental_challenge()
    return True




def elemental_challenge():
    print_slow_bold("Chapter 3 - Elemental challenge")
    print_slow("You have reached the final zone where you could find some secrets of the elixir.")
    print_slow("You should reach the fire temple, which you can see in the south direction.")

    choice3 = input("On the way to the temple, you see a river to be crossed. do you want to drive the boat and cross the river? drive | explore: ").lower()

    if choice3 == "drive":
        print_slow("The water flow is too fast, and you can't drive it in the south direction.")
        print_slow("The boat is pushed towards east, and you get lost in the river.")
        print_slow("Your adventure won't stop here! waiting for you again........")
        print_slow("Your adventure won't stop here! waiting for you again........")
        print_slow_bold("GAME OVER!!! YOU ARE LOST.")
        print_slow_bold(f"SORRY, {player_name}! You are dead now.\n")
        play_again()
        return False

    elif choice3 == "explore":
        explore_choice = input("There is something glowing on the shore. do you want to explore? explore | not explore: ").lower()

        if explore_choice == "not explore":
            print_slow("You haven't found anything and got stuck here. no way to exit.")
            print_slow("Type explore to explore the glowing thing on the shore.")
            print_slow("Your adventure won't stop here! waiting for you again........")
            print_slow_bold("GAME OVER!!! YOU ARE LOST.")
            print_slow_bold(f"SORRY, {player_name}! You are dead now.\n")
            play_again()
            return False

        elif explore_choice == "explore":
            print_slow_bold("Hint: you can cross the river by boat, but you will be carried by the water forever.")
            print_slow("There is only one way to cross the water.")
            print_slow("You should find the person who can dive deep into water.")
            jerry_choice = input("Do you remember jerry? let's call jerry for help. 'hey jerry help': ").lower()

            if jerry_choice == "hey jerry help":
                print_slow(f"Jerry - how can i help you {player_name}? i need to cross this river.")
                print_slow(f"Jerry - sure {player_name}, get on the top of my head i will drop you there.")
                print_slow("Thanks jerry for helping!!!!")
                print_slow("You have crossed the river and now let's move to the fire temple towards south.")
                print_slow("You can see the temple, the temple is glowing with fire.")
                print()
                print_slow_bold("Congratulations! you have completed the challenges and you move to next level")
                return True
    else:
        print_slow_bold("Invalid choice.")
        return False

if __name__ == "__main__":
    demons_hunt()

# %% [markdown]
# Level 4

# %%
def start_gmae():
  level_401()

def play_again():
    choice = input("Do you want to play again? (yes/no): ")
    if choice.lower() == "yes":
        start_game()
    else: #choice.lower() == "no":
        print_slow_slow_bold("Thank you for playing!")
        start_game()

def print_slow(text):
    for char in text:
        print_slow(char, end='', flush=True)
        time.sleep(0.03)
    print_slow()

def print_slow_bold(text):
    for char in text:
        print_slow(f"\033[1m{char}\033[0m", end='', flush=True)
        time.sleep(0.03)
    print_slow()




def level_401():
    print_slow_bold("\n\t\t\tWELCOME TO LEVEL 4 ")
    time.sleep(1)
    print_slow_bold("\n\t\t CHAPTER 1 - CONFRONT THE DEMON")
    time.sleep(1)
    print_slow("\nAs you obtain the elixir, Now it is time to defeat the demons")
    time.sleep(1)
    print_slow_slow("\nYour head is aching hard...")
    time.sleep(1)
    print_slow("\nLet's destroy the demons - 1. Destroy | 2. Explore")
    time.sleep(1)


    choice = int(input("\nEnter your choice 1 | 2 > "))
    time.sleep(1)

    if choice == 2:
        print_slow("\nYou choose to explore")
        time.sleep(1)
        print_slow("\nThe headache increases and")
        time.sleep(1)
        print_slow("\nYou were completely changed into a demon and the world is surrounded by dark")
        time.sleep(1)
        print_slow("\nYour adventure won't stop here!! waiting for you again........")
        time.sleep(1)
        c1 = int(input("\npress 1).To retry, 2).To end the game > "))
        print_slow_bold("GAME OVER!!! YOU ARE LOST.")
        print_slow_bold(f"SORRY, {player_name}! You are dead now.\n")
        play_again()

    elif choice == 1:
        print_slow("\nThere are many demons up there and you can not destroy all at a time")
        time.sleep(1)
        print_slow("\nLet's destroy them one by one...")
        time.sleep(1)
        print_slow("\nRemember if you killed one and by the power of elixir you will obtain the full power from the demon, So choose the order carefully")
        time.sleep(1)
        print_slow("\nOrders for defeating demons - 1. Fire, Water, Air | 2. Water, Air, Fire | 3. Air, Fire, Water")
        time.sleep(1)

        order = int(input("\nEnter your choice - 1, 2, 3 > "))

        if order == 1:
            print_slow("\nYou have destroyed the fire demon")
            time.sleep(1)
            print_slow("\nBut the water demon destroyed you")
            time.sleep(1)
            print_slow("\nYou should understand the nature...")
            time.sleep(1)
            print_slow("\nYour adventure won't stop here!! waiting for you again........")

            print_slow_bold("GAME OVER!!! YOU ARE LOST.")
            print_slow_bold(f"SORRY, {player_name}! You are dead now.\n")
            play_again()
        elif order == 2:
            print_slow("\nYou destroyed water demon")
            time.sleep(1)
            print_slow("\nBut you can't able to destroy the air and fire.")
            time.sleep(1)
            print_slow("\nYou were destroyed by demons.")
            time.sleep(1)
            print_slow("\nYour adventure won't stop here!! waiting for you again........")
            time.sleep(1)
            print_slow_bold("GAME OVER!!! YOU ARE LOST.")
            print_slow_bold(f"SORRY, {player_name}! You are dead now.\n")
            play_again()

        elif order == 3:
            print_slow("\nYou understand the nature elements properly")
            time.sleep(1)
            print_slow("\nYou destroyed all the demons - Air, Fire, and finally Water demons also.")
            time.sleep(1)
            print_slow("\nYou have achieved what you thought, Now you can save this world as you wish to save...")
            time.sleep(1)
            print_slow("\nThe game is not yet over hold your breath")
            time.sleep(1)
            print_slow("\nYou completed chapter 1.")
            time.sleep(1)
            input("\nPress 1 To enter chapter 2 > ")

            level_402()

def level_402():
    print_slow_bold("\n\t\t\tWELCOME TO CHAPTER 2 - USE THE POWER")
    time.sleep(1)
    print_slow("\nAs per your wish let's build a good city for the people,")
    time.sleep(1)
    print_slow("\nWith tall compound walls so that this city will be protected from any other new creatures...")
    time.sleep(1)
    print_slow("\nThe headache increases...")
    time.sleep(1)
    print_slow("\nI think you should cure this headache so that all the works can be done easily")
    time.sleep(1)
    choice = int(input("\nPress 1). To visit a spiritual person 2). To continue building city  > "))

    time.sleep(1)

    if choice == 2:
        print_slow("\nThe buildings were completed...")
        time.sleep(1)
        print_slow("\nNow you were completely changed into demon")
        time.sleep(1)
        print_slow("\nAnd you destroyed the whole town.")
        time.sleep(1)
        print_slow("\nYour adventure won't stop here!! waiting for you again........")
        time.sleep(1)
        print_slow_bold("GAME OVER!!! YOU ARE LOST.")
        print_slow_bold(f"SORRY, {player_name}! You are dead now.\n")
        play_again()

    elif choice == 1:
        time.sleep(1)
        print_slow(f"\nWelcome {player_name} you were changing into a demon step by step")
        time.sleep(1)
        print_slow("\nAs much as the headache increases the level of demon power inside you increases")
        time.sleep(1)

        choice = int(input("\nDo you want to change back to human - 1. Yes | 2. No > "))
        time.sleep(1)

        if choice == 2:
            print_slow("\nYou choose don't change back to human")
            time.sleep(1)
            print_slow("\nYou were completely a demon now!!!")
            time.sleep(1)
            print_slow("\nYou killed the spiritual person and destroyed the city")
            time.sleep(1)
            print_slow("\nThe world is surrounded by dark...")
            time.sleep(1)
            print_slow("\nYour adventure won't stop here!! waiting for you again........")
            time.sleep(1)
            c4 = int(input("\nPress 1). To retry 2). End the game > "))
            print_slow_bold("GAME OVER!!! YOU ARE LOST.")
            print_slow_bold(f"SORRY, {player_name}! You are dead now.\n")
            play_again()

        elif choice == 1:
            print_slow("\nYou chose to change back to human")
            time.sleep(1)
            print_slow("\n\As you choose to change back to human, You should first drop the elixir...")
            time.sleep(1)
            print_slow("\nYou can feel that you are changing into something else that you never expect...")
            time.sleep(1)
            print_slow("\nSlightly you were losing consciousness...")
            time.sleep(1)
            input("\nPress 1 to continue… > ")
            level_403()

def level_403():
    print_slow_bold("\n\t\t\tCHAPTER 3 - END OF ELIXIR")
    time.sleep(1)
    print_slow("\nAs you wake up, You can able to see that half of your face is changed into demon face")
    time.sleep(1)
    print_slow("\nYou should not have the elixir anymore - Destroy it | Throw it")
    time.sleep(1)

    c5 = int(input("\nWhat do you want to do with the elixir 1). Destroy it 2). Throw it > "))
    time.sleep(1)

    if c5 == 2:
            time.sleep(1)
            print_slow("\nYou choose to throw the elixir")
            time.sleep(1)
            print_slow("\nThe elixir has some connection with your body.")
            time.sleep(1)
            print_slow("\nWhen you try to throw the elixir it returns to your hand")
            time.sleep(1)
            print_slow("\nThe elixir never leaves you until you destroy it...")
            time.sleep(1)
            print_slow("\nTry to destroy")
            time.sleep(1)
            c6 = int(input("\npPress 1) To retry 2) To end the game > "))
            print_slow_bold("GAME OVER!!! YOU ARE LOST.")
            print_slow_bold(f"SORRY, {player_name}! You are dead now.\n")
            play_again()

    elif c5 == 1:
            print_slow("\nYou selected to destroy the elixir")
            time.sleep(1)
            print_slow("\nIt is hard the effort of collecting the parts were too hard,")
            time.sleep(1)
            print_slow("\nAnd now you decided to destroy it")
            time.sleep(1)
            choice = input("\nAre you sure you want to destroy it - 1. No | 2. Yes > ")
            if choice == "1":
                print_slow("\nYou refused to destroy the elixir")
                time.sleep(1)
                print_slow("\nIt is the wrong decision you have made")
                time.sleep(1)
                print_slow("\nYou changed into demon completely")
                time.sleep(1)
                print_slow("\nThe world is surrounded by dark")
                time.sleep(1)
                print_slow("\nYour adventure won't stop here!! waiting for you again........")

                print_slow_bold("GAME OVER!!! YOU ARE LOST.")
                print_slow_bold(f"SORRY, {player_name}! You are dead now.\n")
                play_again()

            elif choice == "2":
                print_slow_bold("\nYOU HAVE DESTROYED THE ELIXIR")
                time.sleep(1)
                print_slow_bold("\nNOW YOU SAVE THE WORLD FROM DEMONS")
                time.sleep(1)
                print_slow_bold("\nTHE WORLD IS NOW SAFE")
                time.sleep(1)
                print_slow_bold("\n..........YOU  WON THE GAME..........")

level_401()

# %% [markdown]
# [link text](https://)
